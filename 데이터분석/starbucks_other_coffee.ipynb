# %%
import pandas as pd

df_starbugs = pd.read_csv('starbucks_seoul.csv')
df_starbugs
# Out:
#          store                                   addr        lat         lng
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 662      면목역                  서울특별시 중랑구 면목로 403 (면목동)  37.587880  127.087609
# 663       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 664      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 665      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 666      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [667 rows x 4 columns]

# %%
df_starbugs = df_starbugs.set_axis(['지점명', '지점주소', '지점위도', '지점경도'], axis=1).reset_index(drop=True)
df_starbugs
# Out:
#            지점명                                   지점주소       지점위도        지점경도
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 662      면목역                  서울특별시 중랑구 면목로 403 (면목동)  37.587880  127.087609
# 663       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 664      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 665      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 666      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [667 rows x 4 columns]

# %%
df = pd.read_csv('소상공인시장진흥공단_상가(상권)정보_서울_202510.csv', low_memory=False)
df
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220802495368  영어독서클럽영어교습소  NaN        P1       교육      P105
# 1       MA010120220806509545         하루달곰  NaN        I2       음식      I210
# 2       MA010120220804193917          양산박  NaN        I2       음식      I201
# 3       MA010120220805914597   으뜸공인중개사사무소  NaN        L1      부동산      L102
# 4       MA010120220814395227        세선티알엠  NaN        N1  시설관리·임대      N103
# ...                      ...          ...  ...       ...      ...       ...
# 536257  MA0101202306A0044326          신인류  NaN        I2       음식      I211
# 536258  MA0101202306A0026957            휴  NaN        I2       음식      I201
# 536259  MA0101202306A0041780     참기름짜는육회집  NaN        I2       음식      I201
# 536260  MA0101202306A0033595   신사공인중개사사무소  NaN        L1      부동산      L102
# 536261  MA0101202306A0015005         거마농장  NaN        I2       음식      I201
#
#        상권업종중분류명 상권업종소분류코드       상권업종소분류명 표준산업분류코드  ...  \
# 0         일반 교육    P10501        입시·교과학원   P85631  ...
# 1         기타 간이    I21001           빵/도넛   I56191  ...
# 2            한식    I20101         백반/한정식   I56111  ...
# 3       부동산 서비스    L10203     부동산 중개/대리업   L68221  ...
# 4         조경·유지    N10301  조경 유지·관리 서비스업   N74300  ...
# ...         ...       ...            ...      ...  ...
# 536257       주점    I21104          요리 주점   I56219  ...
# 536258       한식    I20101         백반/한정식   I56111  ...
# 536259       한식    I20108       소고기 구이/찜   I56113  ...
# 536260  부동산 서비스    L10203     부동산 중개/대리업   L68221  ...
# 536261       한식    I20107      돼지고기 구이/찜   I56113  ...
#
#                            건물관리번호       건물명                  도로명주소   구우편번호  \
# 0       1150010200106960000025433  세신그린코아빌딩   서울특별시 강서구 공항대로41길 51  157930
# 1       1135010500113100000008002     비콘드림힐  서울특별시 노원구 상계로1길 82-14  139816
# 2       1165010200102670000002838      명칭없음   서울특별시 서초구 언남11길 34-1  137895
# 3       1144010900100100132005798       NaN      서울특별시 마포구 숭문길 182  121870
# 4       1162010200103050030004243       NaN      서울특별시 관악구 호암로 538  151929
# ...                           ...       ...                    ...     ...
# 536257  1111013800100840003013815       NaN      서울특별시 종로구 종로 72-1  110122
# 536258  1168010100107350017000001  역삼푸르지오시티    서울특별시 강남구 논현로85길 52  135923
# 536259  1171011100101460008016117       NaN  서울특별시 송파구 백제고분로48길 19  138832
# 536260  1168010700105660018010886       NaN   서울특별시 강남구 논현로157길 18  135891
# 536261  1171011300100360013023025     동인빌타운     서울특별시 송파구 거마로2길 24  138814
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 0       7586  NaN  NaN  NaN  126.845780  37.560238
# 1       1693  301  NaN  NaN  127.062003  37.659314
# 2       6776  NaN    1  NaN  127.043051  37.475637
# 3       4122  NaN    1  NaN  126.946651  37.554524
# 4       8821  NaN  NaN  NaN  126.931669  37.465579
# ...      ...  ...  ...  ...         ...        ...
# 536257  3189  NaN    4  NaN  126.985466  37.569952
# 536258  6235  NaN    2  NaN  127.033813  37.498192
# 536259  5632  NaN    1  NaN  127.115414  37.511187
# 536260  6032  NaN    1  NaN  127.026663  37.522512
# 536261  5768  NaN  NaN  NaN  127.147309  37.493249
#
# [536262 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536262 entries, 0 to 536261
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     536262 non-null  object
#  1   상호명        536262 non-null  object
#  2   지점명        47467 non-null   object
#  3   상권업종대분류코드  536262 non-null  object
#  4   상권업종대분류명   536262 non-null  object
#  5   상권업종중분류코드  536262 non-null  object
#  6   상권업종중분류명   536262 non-null  object
#  7   상권업종소분류코드  536262 non-null  object
#  8   상권업종소분류명   536262 non-null  object
#  9   표준산업분류코드   536061 non-null  object
#  10  표준산업분류명    536061 non-null  object
#  11  시도코드       536262 non-null  int64
#  12  시도명        536262 non-null  object
#  13  시군구코드      536262 non-null  int64
#  14  시군구명       536262 non-null  object
#  15  행정동코드      536262 non-null  int64
#  16  행정동명       536262 non-null  object
#  17  법정동코드      536262 non-null  int64
#  18  법정동명       536262 non-null  object
#  19  지번코드       536262 non-null  int64
#  20  대지구분코드     536262 non-null  int64
#  21  대지구분명      536262 non-null  object
#  22  지번본번지      536237 non-null  float64
#  23  지번부번지      441464 non-null  float64
#  24  지번주소       536262 non-null  object
#  25  도로명코드      536262 non-null  int64
#  26  도로명        536262 non-null  object
#  27  건물본번지      536260 non-null  float64
#  28  건물부번지      69643 non-null   float64
#  29  건물관리번호     533880 non-null  object
#  30  건물명        261482 non-null  object
#  31  도로명주소      536262 non-null  object
#  32  구우편번호      536262 non-null  int64
#  33  신우편번호      536262 non-null  int64
#  34  동정보        53289 non-null   object
#  35  층정보        356978 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         536262 non-null  float64
#  38  위도         536262 non-null  float64
# dtypes: float64(7), int64(9), object(23)
# memory usage: 159.6+ MB

# %%
shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']

# %%
df[df["상호명"].str.contains("메가엠지씨", case=False, na=False)]
# Out:
#                       상가업소번호               상호명   지점명 상권업종대분류코드 상권업종대분류명  \
# 3223    MA0101202301A0006057       메가엠지씨커피노원역점   NaN        I2       음식
# 3321    MA0101202302A0108581    메가엠지씨커피여의도KBS점   NaN        I2       음식
# 3580    MA0101202302A0054476    메가엠지씨커피올림픽공원역점   NaN        I2       음식
# 4036    MA0101202302A0078446       메가엠지씨커피방배카페   거리점        I2       음식
# 4389    MA0101202302A0024271         메가엠지씨커피강남   자곡점        I2       음식
# ...                      ...               ...   ...       ...      ...
# 534236  MA0101202306A0046682   메가엠지씨커피강남못골도서관점   NaN        I2       음식
# 535302  MA0101202306A0037162      메가엠지씨커피충무로역점   NaN        I2       음식
# 535887  MA0101202306A0065301         메가엠지씨커피삼성  중앙역점        I2       음식
# 536142  MA0101202306A0013543  메가엠지씨커피가산그레이트밸리점   NaN        I2       음식
# 536187  MA0101202305A0037173       메가엠지씨커피고덕역점   NaN        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 3223        I212    비알코올     I21201       카페   I56221  ...
# 3321        I212    비알코올     I21201       카페   I56221  ...
# 3580        I212    비알코올     I21201       카페   I56221  ...
# 4036        I212    비알코올     I21201       카페   I56221  ...
# 4389        I212    비알코올     I21201       카페   I56221  ...
# ...          ...      ...       ...      ...      ...  ...
# 534236      I212    비알코올     I21201       카페   I56221  ...
# 535302      I212    비알코올     I21201       카페   I56221  ...
# 535887      I212    비알코올     I21201       카페   I56221  ...
# 536142      I212    비알코올     I21201       카페   I56221  ...
# 536187      I212    비알코올     I21201       카페   I56221  ...
#
#                            건물관리번호          건물명                   도로명주소  \
# 3223    1135010500107090002000001         메가빌딩       서울특별시 노원구 노해로 459
# 3321    1156011000100170000031660  여의도더샵아일랜드파크     서울특별시 영등포구 의사당대로 38
# 3580    1171011100100890011015454       올림픽프라자     서울특별시 송파구 양재대로 1222
# 4036    1165010100107600002015591          NaN     서울특별시 서초구 방배중앙로 188
# 4389    1168011200106580000000001    강남힐스테이트에코       서울특별시 강남구 자곡로 202
# ...                           ...          ...                     ...
# 534236  1168011200106360000000001        서강프라자       서울특별시 강남구 자곡로 114
# 535302  1114013700100510011017687         하니맨션        서울특별시 중구 퇴계로 195
# 535887  1168010500101190000026276          NaN      서울특별시 강남구 봉은사로 478
# 536142  1154510100100600005000001     갑을그레이트밸리     서울특별시 금천구 디지털로9길 32
# 536187  1174010100100470010018714         성은빌딩  서울특별시 강동구 동남로75길 13-15
#
#          구우편번호 신우편번호  동정보 층정보  호정보          경도         위도
# 3223    139942  1689  NaN   1  NaN  127.058996  37.654252
# 3321    150916  7236  102   1  NaN  126.918208  37.525550
# 3580    138151  5648  NaN   1  NaN  127.131064  37.515730
# 4036    137828  6553    2   1  NaN  126.985887  37.495682
# 4389    135190  6373  NaN   1  NaN  127.105002  37.474697
# ...        ...   ...  ...  ..  ...         ...        ...
# 534236  135190  6373  NaN   1  NaN  127.096023  37.472056
# 535302  100867  4557  NaN   1  NaN  126.993583  37.561357
# 535887  135509  6154  NaN   1  NaN  127.052777  37.512637
# 536142  153709  8512  NaN   1  NaN  126.887280  37.479636
# 536187  134825  5269  NaN   1  NaN  127.155496  37.553623
#
# [812 rows x 39 columns]

# %%
df[df["상호명"].str.contains("메가커피", case=False, na=False)]
# Out:
#                       상가업소번호           상호명    지점명 상권업종대분류코드 상권업종대분류명  \
# 1810    MA010120220808836788      메가커피고투몰점    NaN        I2       음식
# 5975    MA010120220811952416       메가커피서울대    입구점        I2       음식
# 7389    MA010120220813125772     메가커피수락산역점    NaN        I2       음식
# 41536   MA010120220808992892    메가커피북한산정릉점    NaN        I2       음식
# 43300   MA010120220800505619         메가커피우    장산점        I2       음식
# 53150   MA010120220814193356      메가커피동소문점    NaN        I2       음식
# 55603   MA010120220805197325        메가커피노원   로데오점        I2       음식
# 96952   MA010120220802678209        메가커피문정  아이파크점        I2       음식
# 104923  MA010120220812196839     메가커피문정로데오    NaN        I2       음식
# 107486  MA010120220803145703        메가커피현대    시장점        I2       음식
# 111754  MA010120220811858271      메가커피상계역점    NaN        I2       음식
# 120101  MA010120220807070602          메가커피    NaN        I2       음식
# 120378  MA010120220808157025     메가커피노량진역점    NaN        I2       음식
# 131906  MA010120220808463723          메가커피    NaN        I2       음식
# 134823  MA010120220810074917     메가커피사가정역점    NaN        I2       음식
# 154043  MA010120220813957016          메가커피   화곡역점        I2       음식
# 154132  MA010120220804156243     메가커피신도림역점    NaN        I2       음식
# 173617  MA010120220812511902          메가커피    공덕점        I2       음식
# 177280  MA010120220803387874        메가커피신곡    시장점        I2       음식
# 177847  MA010120220814337194        메가커피신창    시장점        I2       음식
# 184440  MA010120220804149613          메가커피    장안점        I2       음식
# 199505  MA010120220810112788      메가커피양천신정    중앙점        I2       음식
# 217097  MA010120220808147311      메가커피수색자이    NaN        I2       음식
# 231762  MA010120220806689213        메가커피이수    태평점        I2       음식
# 231867  MA010120220804461630      메가커피지하도점    강남역        I2       음식
# 241908  MA010120220812962899  메가커피공덕SK리더스뷰    NaN        I2       음식
# 256898  MA010120220800186190     식빵은여기메가커피    NaN        I2       음식
# 264300  MA010120220802241927          메가커피    마곡점        I2       음식
# 271487  MA010120220813292922      메가커피신월경창    시장점        I2       음식
# 284389  MA010120220804968967     메가커피잠실레이크   팰리스점        I2       음식
권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 1810        I212    비알코올     I21201       카페   I56191  ...
# 3223        I212    비알코올     I21201       카페   I56221  ...
# 3321        I212    비알코올     I21201       카페   I56221  ...
# 3580        I212    비알코올     I21201       카페   I56221  ...
# 4036        I212    비알코올     I21201       카페   I56221  ...
# ...          ...      ...       ...      ...      ...  ...
# 534236      I212    비알코올     I21201       카페   I56221  ...
# 535302      I212    비알코올     I21201       카페   I56221  ...
# 535887      I212    비알코올     I21201       카페   I56221  ...
# 536142      I212    비알코올     I21201       카페   I56221  ...
# 536187      I212    비알코올     I21201       카페   I56221  ...
#
#                            건물관리번호          건물명                   도로명주소  \
# 1810    1165010700100190003000001        지하도상가      서울특별시 서초구 신반포로 176
# 3223    1135010500107090002000001         메가빌딩       서울특별시 노원구 노해로 459
# 3321    1156011000100170000031660  여의도더샵아일랜드파크     서울특별시 영등포구 의사당대로 38
# 3580    1171011100100890011015454       올림픽프라자     서울특별시 송파구 양재대로 1222
# 4036    1165010100107600002015591          NaN     서울특별시 서초구 방배중앙로 188
# ...                           ...          ...                     ...
# 534236  1168011200106360000000001        서강프라자       서울특별시 강남구 자곡로 114
# 535302  1114013700100510011017687         하니맨션        서울특별시 중구 퇴계로 195
# 535887  1168010500101190000026276          NaN      서울특별시 강남구 봉은사로 478
# 536142  1154510100100600005000001     갑을그레이트밸리     서울특별시 금천구 디지털로9길 32
# 536187  1174010100100470010018714         성은빌딩  서울특별시 강동구 동남로75길 13-15
#
#          구우편번호 신우편번호  동정보  층정보  호정보          경도         위도
# 1810    137726  6546    G  NaN  NaN  127.002409  37.503936
# 3223    139942  1689  NaN    1  NaN  127.058996  37.654252
# 3321    150916  7236  102    1  NaN  126.918208  37.525550
# 3580    138151  5648  NaN    1  NaN  127.131064  37.515730
# 4036    137828  6553    2    1  NaN  126.985887  37.495682
# ...        ...   ...  ...  ...  ...         ...        ...
# 534236  135190  6373  NaN    1  NaN  127.096023  37.472056
# 535302  100867  4557  NaN    1  NaN  126.993583  37.561357
# 535887  135509  6154  NaN    1  NaN  127.052777  37.512637
# 536142  153709  8512  NaN    1  NaN  126.887280  37.479636
# 536187  134825  5269  NaN    1  NaN  127.155496  37.553623
#
# [852 rows x 39 columns]

# %%
df_shop = df.copy()

# shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']
# 이디야|이디아커피|올리브영|컴포즈커피|빽다방|백다방|메가커피|메가엠지씨|메가MGC
# extract(): 특정 문자열을 포함하고 있으면 그 문자열을 반환, 포함하고 있지 않으면 NaN을 반환
df_shop['상호명'] = df_shop['상호명'].str.extract('({})'.format('|'.join(shop)))
df_shop['상호명']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 536257    NaN
# 536258    NaN
# 536259    NaN
# 536260    NaN
# 536261    NaN
# Name: 상호명, Length: 536262, dtype: object

# %%
 
df_shop = df_shop.dropna(subset=['상호명']).iloc[:, [0, 1, 14, 37, 38]].reset_index(drop=True)
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220801142601    이디야  영등포구  126.888601  37.526796
# 1     MA010120220808836788   메가커피   서초구  127.002409  37.503936
# 2     MA010120220812797025  컴포즈커피   종로구  126.987638  37.578016
# 3     MA010120220814215158  컴포즈커피   도봉구  127.027834  37.660084
# 4     MA010120220808574817    빽다방   광진구  127.093411  37.535353
# ...                    ...    ...   ...         ...        ...
# 2537  MA0101202306A0037570  컴포즈커피   강서구  126.861494  37.545526
# 2538  MA0101202306A0097799  컴포즈커피   강남구  127.033021  37.497580
# 2539  MA0101202306A0013543  메가엠지씨   금천구  126.887280  37.479636
# 2540  MA0101202305A0037173  메가엠지씨   강동구  127.155496  37.553623
# 2541  MA0101202305A0039797    이디야   노원구  127.080375  37.670827
#
# [2542 rows x 5 columns]

# %%
df_shop['상호명'] = df_shop['상호명'].str.replace('메가엠지씨', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('메가MGC', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('이디아커피', '이디야', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('백다방', '빽다방', regex=False)
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220801142601    이디야  영등포구  126.888601  37.526796
# 1     MA010120220808836788   메가커피   서초구  127.002409  37.503936
# 2     MA010120220812797025  컴포즈커피   종로구  126.987638  37.578016
# 3     MA010120220814215158  컴포즈커피   도봉구  127.027834  37.660084
# 4     MA010120220808574817    빽다방   광진구  127.093411  37.535353
# ...                    ...    ...   ...         ...        ...
# 2537  MA0101202306A0037570  컴포즈커피   강서구  126.861494  37.545526
# 2538  MA0101202306A0097799  컴포즈커피   강남구  127.033021  37.497580
# 2539  MA0101202306A0013543   메가커피   금천구  126.887280  37.479636
# 2540  MA0101202305A0037173   메가커피   강동구  127.155496  37.553623
# 2541  MA0101202305A0039797    이디야   노원구  127.080375  37.670827
#
# [2542 rows x 5 columns]

# %%
df_shop[df_shop['상호명'].str.contains('메가엠지씨', na=False)]
# Out:
# Empty DataFrame
# Columns: [상가업소번호, 상호명, 시군구명, 경도, 위도]
# Index: []

# %%
df_cross = df_shop.merge(df_starbugs, how='cross')
df_cross
# Out:
#                        상가업소번호  상호명  시군구명          경도         위도        지점명  \
# 0        MA010120220801142601  이디야  영등포구  126.888601  37.526796  역삼아레나빌딩
# 1        MA010120220801142601  이디야  영등포구  126.888601  37.526796   논현역사거리
# 2        MA010120220801142601  이디야  영등포구  126.888601  37.526796  신사역성일빌딩
# 3        MA010120220801142601  이디야  영등포구  126.888601  37.526796   국기원사거리
# 4        MA010120220801142601  이디야  영등포구  126.888601  37.526796   대치재경빌딩
# ...                       ...  ...   ...         ...        ...        ...
# 1695509  MA0101202305A0039797  이디야   노원구  127.080375  37.670827      면목역
# 1695510  MA0101202305A0039797  이디야   노원구  127.080375  37.670827       묵동
# 1695511  MA0101202305A0039797  이디야   노원구  127.080375  37.670827      망우동
# [1695514 rows x 10 columns]

# %%
df_dis = df_cross.groupby(['상가업소번호','상호명'])['거리'].min().reset_index()
df_dis
# Out:
#                     상가업소번호    상호명           거리
# 0     MA010120220800021713  컴포즈커피   692.058445
# 1     MA010120220800024620    이디야    95.740366
# 2     MA010120220800026176    이디야  1115.073437
# 3     MA010120220800033480    이디야    81.912918
# 4     MA010120220800033806    이디야   351.880382
# ...                    ...    ...          ...
# 2537  MA0106202508A0382188    이디야   182.194030
# 2538  MA0106202508A2292809   올리브영    94.825689
# 2539  MA0106202508A2292811   올리브영    54.560486
# 2540  MA0106202508A2293408   올리브영    21.351847
# 2541  MA0106202508A2293410   올리브영    32.530233
#
# [2542 rows x 3 columns]

# %%
df_dis.groupby('상호명')['거리'].mean()
# Out:
# 상호명
# 메가커피     374.960544
# 빽다방      296.631446
# 올리브영     200.563616
# 이디야      379.663058
# 컴포즈커피    342.560412
# Name: 거리, dtype: float64

# %%
df_dis.groupby(['상호명'])['거리'].agg(['mean','count'])
# Out:
#              mean  count
# 상호명
# 메가커피   374.960544    861
# 빽다방    296.631446    360
# 올리브영   200.563616    432
# 이디야    379.663058    453
# 컴포즈커피  342.560412    436

# %%
# 거리를 입력하면 프렌차이즈 별 스타벅스와의 평균거리와 매장개수를 출력하는 함수
def distance(x):
    dis = df_dis['거리'] <= x
    return df_dis[dis].groupby('상호명')['거리'].agg(['mean', 'count'])
    
distance(100)
# Out:
#             mean  count
# 상호명
# 메가커피   60.831928    152
# 빽다방    62.961478     91
# 올리브영   52.499012    197
# 이디야    67.858056     81
# 컴포즈커피  62.892064     89

# %%
# !pip install pandasecharts
# Out:
# Collecting pandasecharts
#   Downloading pandasecharts-0.5-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pandasecharts) (2.3.3)
# Collecting pyecharts>=1.0.0 (from pandasecharts)
#   Downloading pyecharts-2.0.9-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jinja2 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.1.6)
# Collecting prettytable (from pyecharts>=1.0.0->pandasecharts)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Collecting simplejson (from pyecharts>=1.0.0->pandasecharts)
#   Downloading simplejson-3.20.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from jinja2->pyecharts>=1.0.0->pandasecharts) (3.0.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pandas->pandasecharts) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pandas->pandasecharts) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandasecharts) (1.17.0)
# Requirement already satisfied: wcwidth in c:\users\김기영\appdata\local\programs\python\python311\lib\site-packages (from prettytable->pyecharts>=1.0.0->pandasecharts) (0.2.14)
# Downloading pandasecharts-0.5-py3-none-any.whl (15 kB)
# Downloading pyecharts-2.0.9-py3-none-any.whl (153 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading simplejson-3.20.2-cp311-cp311-win_amd64.whl (75 kB)
# Installing collected packages: simplejson, prettytable, pyecharts, pandasecharts
#
#    ---------------------------------------- 0/4 [simplejson]
#    ---------------------------------------- 0/4 [simplejson]
#    ---------------------------------------- 0/4 [simplejson]
#    ---------------------------------------- 0/4 [simplejson]
#    ---------------------------------------- 0/4 [simplejson]
#    ---------- ----------------------------- 1/4 [prettytable]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    -------------------- ------------------- 2/4 [pyecharts]
#    ------------------------------ --------- 3/4 [pandasecharts]
#    ---------------------------------------- 4/4 [pandasecharts]
#
# Successfully installed pandasecharts-0.5 prettytable-3.17.0 pyecharts-2.0.9 simplejson-3.20.2

# %%
df_100 = distance(100).reset_index()
df_100
# Out:
#      상호명       mean  count
# 0   메가커피  60.831928    152
# 1    빽다방  62.961478     91
# 2   올리브영  52.499012    197
# 3    이디야  67.858056     81
# 4  컴포즈커피  62.892064     89

# %%
import IPython
from pandasecharts import echart

df_100.echart.pie(x='상호명', y='count', figsize=(600, 400),
                  radius=['20%', '60%'], label_opts={'position':'outer'},
                  title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                  legend_opts={'pos_right':'0%', 'orient':'vertical'},
                  subtitle='100m 이내 매장수', init_opts={'bg_color': 'white'}).render()

IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="https://assets.pyecharts.org/assets/v5/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="adf157cd1a2c4c6087093520b723e887" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_adf157cd1a2c4c6087093520b723e887 = echarts.init(
#             document.getElementById('adf157cd1a2c4c6087093520b723e887'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_adf157cd1a2c4c6087093520b723e887 = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "count",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\uba54\uac00\ucee4\ud53c",
#                     "value": 152
#                 },
#                 {
#                     "name": "\ube7d\ub2e4\ubc29",
#                     "value": 91
#                 },
#                 {
#                     "name": "\uc62c\ub9ac\ube0c\uc601",
#                     "value": 197
#                 },
#                 {
#                     "name": "\uc774\ub514\uc57c",
#                     "value": 81
#                 },
#                 {
#                     "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                     "value": 89
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outer",
#                 "margin": 8,
#                 "formatter": "{b}:{d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uba54\uac00\ucee4\ud53c",
#                 "\ube7d\ub2e4\ubc29",
#                 "\uc62c\ub9ac\ube0c\uc601",
#                 "\uc774\ub514\uc57c",
#                 "\ucef4\ud3ec\uc988\ucee4\ud53c"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "0%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\ucee4\ud53c \ud504\ub80c\ucc28\uc774\uc988\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \uc2a4\ud0c0\ubc85\uc2a4 \uc606\uc778\uac00?",
#             "target": "blank",
#             "subtext": "100m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_adf157cd1a2c4c6087093520b723e887.setOption(option_adf157cd1a2c4c6087093520b723e887);
#     </script>
# </body>
# </html>

# %%
from pyecharts.charts import Timeline, Grid

tl = Timeline({'width':'600px', 'height':'400px'})

for i in [1000, 100, 50, 30]:
    df_d = distance(i).reset_index()
    pie1 = df_d.echart.pie(x='상호명', y='count', figsize=(600, 400),
                    radius=['20%', '60%'], label_opts={'position':'outer'},
                    title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                    legend_opts={'pos_right':'0%', 'orient':'vertical'},
                    subtitle='{}m 이내 매장수'.format(i), init_opts={'bg_color': 'white'})
    tl.add(pie1, '{}m'.format(i)).render()
IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="https://assets.pyecharts.org/assets/v5/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="81dbe53d422d422fbcf0cf282718a4b1" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_81dbe53d422d422fbcf0cf282718a4b1 = echarts.init(
#             document.getElementById('81dbe53d422d422fbcf0cf282718a4b1'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_81dbe53d422d422fbcf0cf282718a4b1 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "count",
#                 "colorBy": "data",
#                 "legendHoverLink": true,
#                 "selectedMode": false,
#                 "selectedOffset": 10,
#                 "clockwise": true,
#                 "startAngle": 90,
#                 "minAngle": 0,
#                 "minShowLabelAngle": 0,
#                 "avoidLabelOverlap": true,
#                 "stillShowZeroSum": true,
#                 "percentPrecision": 2,
#                 "showEmptyCircle": true,
#                 "emptyCircleStyle": {
#                     "color": "lightgray",
#                     "borderColor": "#000",
#                     "borderWidth": 0,
#                     "borderType": "solid",
#                     "borderDashOffset": 0,
#                     "borderCap": "butt",
#                     "borderJoin": "bevel",
#                     "borderMiterLimit": 10,
#                     "opacity": 1
#                 },
#                 "data": [
#                     {
#                         "name": "\uba54\uac00\ucee4\ud53c",
#                         "value": 22
#                     },
#                     {
#                         "name": "\ube7d\ub2e4\ubc29",
#                         "value": 10
#                     },
#                     {
#                         "name": "\uc62c\ub9ac\ube0c\uc601",
#                         "value": 56
#                     },
#                     {
#                         "name": "\uc774\ub514\uc57c",
#                         "value": 7
#                     },
#                     {
#                         "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                         "value": 13
#                     }
#                 ],
#                 "radius": [
#                     "20%",
#                     "60%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "outer",
#                     "margin": 8,
#                     "formatter": "{b}:{d}%",
#                     "valueAnimation": false
#                 },
#                 "labelLine": {
#                     "show": true,
#                     "showAbove": false,
#                     "length": 15,
#                     "length2": 15,
#                     "smooth": false,
#                     "minTurnAngle": 90,
#                     "maxSurfaceAngle": 90
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "1000m",
#                 "100m",
#                 "50m",
#                 "30m"
#             ]
#         },
#         "legend": [
#             {
#                 "data": [
#                     "\uba54\uac00\ucee4\ud53c",
#                     "\ube7d\ub2e4\ubc29",
#                     "\uc62c\ub9ac\ube0c\uc601",
#                     "\uc774\ub514\uc57c",
#                     "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                 ],
#                 "selected": {},
#                 "show": true,
#                 "right": "0%",
#                 "orient": "vertical",
#                 "padding": 5,
#                 "itemGap": 10,
#                 "itemWidth": 25,
#                 "itemHeight": 14,
#                 "backgroundColor": "transparent",
#                 "borderColor": "#ccc",
#                 "borderRadius": 0,
#                 "pageButtonItemGap": 5,
#                 "pageButtonPosition": "end",
#                 "pageFormatter": "{current}/{total}",
#                 "pageIconColor": "#2f4554",
#                 "pageIconInactiveColor": "#aaa",
#                 "pageIconSize": 15,
#                 "animationDurationUpdate": 800,
#                 "selector": false,
#                 "selectorPosition": "auto",
#                 "selectorItemGap": 7,
#                 "selectorButtonGap": 10
#             }
#         ]
#     },
#     "options": [
#         {
#             "backgroundColor": "white",
#             "legend": [
#                 {
#                     "data": [
#                         "\uba54\uac00\ucee4\ud53c",
#                         "\ube7d\ub2e4\ubc29",
#                         "\uc62c\ub9ac\ube0c\uc601",
#                         "\uc774\ub514\uc57c",
#                         "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14,
#                     "backgroundColor": "transparent",
#                     "borderColor": "#ccc",
#                     "borderRadius": 0,
#                     "pageButtonItemGap": 5,
#                     "pageButtonPosition": "end",
#                     "pageFormatter": "{current}/{total}",
#                     "pageIconColor": "#2f4554",
#                     "pageIconInactiveColor": "#aaa",
#                     "pageIconSize": 15,
#                     "animationDurationUpdate": 800,
#                     "selector": false,
#                     "selectorPosition": "auto",
#                     "selectorItemGap": 7,
#                     "selectorButtonGap": 10
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "colorBy": "data",
#                     "legendHoverLink": true,
#                     "selectedMode": false,
#                     "selectedOffset": 10,
#                     "clockwise": true,
#                     "startAngle": 90,
#                     "minAngle": 0,
#                     "minShowLabelAngle": 0,
#                     "avoidLabelOverlap": true,
#                     "stillShowZeroSum": true,
#                     "percentPrecision": 2,
#                     "showEmptyCircle": true,
#                     "emptyCircleStyle": {
#                         "color": "lightgray",
#                         "borderColor": "#000",
#                         "borderWidth": 0,
#                         "borderType": "solid",
#                         "borderDashOffset": 0,
#                         "borderCap": "butt",
#                         "borderJoin": "bevel",
#                         "borderMiterLimit": 10,
#                         "opacity": 1
#                     },
#                     "data": [
#                         {
#                             "name": "\uba54\uac00\ucee4\ud53c",
#                             "value": 815
#                         },
#                         {
#                             "name": "\ube7d\ub2e4\ubc29",
#                             "value": 348
#                         },
#                         {
#                             "name": "\uc62c\ub9ac\ube0c\uc601",
#                             "value": 420
